# %% [markdown]
# # Hylas (TYPE 2) - custom prediction using Sherlock methods

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Generate data sets from extracted CSV product column data

# %%
import os
import re
from ast import literal_eval
import pandas
import pyarrow.parquet as pq
import pyarrow.csv as pc
from datetime import datetime
import multiprocessing
from functools import partial

def tryeval(val):
  try:
    val=literal_eval(val)
  except (ValueError, SyntaxError):
    pass
  return val


def row_value_processor_one(row):
    return row


def row_value_processor_csv(row):
    first, values = row.split(',', 1)
    
    return first, values


def row_filter_one(row):
    return True


def row_filter_csv(row_tuple, filter_value):
    #print(f'"{row_tuple[0]}" == "{filter_value}"')
    
    return row_tuple[0] == filter_value


def unpack_row_one(row):
    return row


def unpack_row_csv(row_tuple):
    return row_tuple[1]


# Declare pool AFTER methods that will be later called from pool.
pool = multiprocessing.Pool(os.cpu_count())


pattern = re.compile(r"^[{]?[0-9a-fA-F]{8}-([0-9a-fA-F]{4}-){3}[0-9a-fA-F]{12}[}]?$")

# this is actually a directory, and not a file as it might appear from this path
by_column = '/Users/lowecg/source/labs/data/xml-discover/.cache/5e71870f-b7e2-48eb-9ca0-1ee67fe59845_ipp_productinfo_eu_20201030130300.xml'

print(f'Treating file data with {os.cpu_count()} cores')


start = datetime.now()

df_labels = pandas.DataFrame(columns=['type'])
df_samples = pandas.DataFrame(columns=['values'])

idx = 0

ignored_files = []

for file_name in os.listdir(by_column):
  if pattern.match(file_name):
    with open (by_column + '/' + file_name, 'r') as attributes_file:
      data=attributes_file.readlines()
    
      label = str.strip(data[0])
        
      values = label.split(',')
    
      if len(values) > 1:
        row_processor = row_value_processor_csv
        # peek at first data row, and use the first column as a filter value
        filter_value = data[1].split(',')[0] if len(data)>0 else None
        
        #print(f'row = "{data[1]}", filter value = "{filter_value}"')
        
        row_filter = partial(row_filter_csv, filter_value=filter_value)
        unpack_row = unpack_row_csv
        label = values[1]
      else:
        row_processor = row_value_processor_one
        row_filter = row_filter_one
        unpack_row = unpack_row_one

      print(f'Processing "{file_name}" -> "{label}"')
    
      idx += 1
        
      df_labels.loc[idx, 'type'] = label
    
        
      to_store = str(list(pool.map(tryeval, map(unpack_row, filter(row_filter, map(row_processor, map(str.strip, data[1:])))))))
    
      df_samples.loc[idx, 'values'] = to_store
  else:
    ignored_files.append(file_name)
    
    
print('IGNORED: ', ignored_files)

    
print('Saving to parquet')
    
df_labels.to_parquet(fname='myfile_labels.parquet',engine='auto',compression='snappy')
df_samples.to_parquet(fname='myfile_values.parquet',engine='auto',compression='snappy')

end = datetime.now()
x = end - start
print(f'Write process took {x} seconds.')
# Out:
# Treating file data with 8 cores
# Processing "a9f8041c-1072-4628-8081-82f931eae137" -> "/products/PRODUCT/attributes/attribute/Access Code"
# Processing "bb2d07c3-c777-4525-8017-41c9ef4333b6" -> "/products/PRODUCT/sizes/size/packageheight"
# Processing "9e2384d0-2031-4139-a08b-cf83a14f5b04" -> "/products/PRODUCT/attributes/attribute/Simple Color"
# Processing "1cd73091-e357-4051-89e2-92e8003d2435" -> "/products/PRODUCT/prices/price/country (a)"
# Processing "9647cbf9-ab8c-4cf4-a612-037fc22b5f63" -> "/products/PRODUCT/attributes/attribute/Hat Type"
# Processing "e511878a-fb0a-4d07-8e26-f6f0e99b9307" -> "/products/PRODUCT/attributes/attribute/Bag Type"
# Processing "44dc383c-7386-4fa0-aea8-6217b855b57e" -> "/products/PRODUCT/attributes/attribute/Gift Collections"
# Processing "7a1e72e0-1116-449e-bcc2-46df87f574d5" -> "/products/PRODUCT/attributes/attribute/Store - Name Change Test"
# Processing "f374185a-656d-49f1-9542-0b41e204fc1e" -> "/products/PRODUCT/attributes/attribute/Global Football Use (FCB)"
# Processing "6d5eb2ea-e3d6-4d6a-9d05-6598a9dbaad7" -> "/products/PRODUCT/attributes/attribute/CMS Enhanced PDP Content"
# Processing "adc85064-7785-45aa-b289-20267987da4d" -> "/products/PRODUCT/attributes/attribute/Jersey Grade"
# Processing "332e87ca-0fc3-4972-9da5-b200ea36cdad" -> "/products/PRODUCT/widthgroupid"
# Processing "9e12e89a-4385-4efa-8e61-19298731f0c7" -> "/products/PRODUCT/attributes/attribute/Best For - Global Football Shoes"
# Processing "8cf69d48-61c6-4f24-b167-0c625d89c457" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Products"
# Processing "df3d9847-173e-40c2-8697-336af2c246a5" -> "/products/PRODUCT/attributes/attribute/Best For - Clothing"
# Processing "66b7477b-5de8-43fd-a898-ba8385e12346" -> "/products/PRODUCT/attributes/attribute/Gifts"
# Processing "f4107ddd-fbdf-45b2-b962-a1e56913e64c" -> "/products/PRODUCT/attributes/attribute/Secondary Color"
# Processing "cee06127-2d8e-44e6-939c-bc80cd818805" -> "/products/PRODUCT/attributes/attribute/Athlete"
# Processing "5dd7d151-fbc6-47c1-932c-fc30cb3ddc65" -> "/products/PRODUCT/attributes/attribute/Details"
# Processing "8baa74b4-3180-414e-ac9a-05dcfddf1dd4" -> "/products/PRODUCT/attributes/attribute/Endeca Secondary Simple Colour"
# Processing "b5cf9315-b6c2-42ed-b037-d647e5c96bbc" -> "/products/PRODUCT/attributes/attribute/Hide From Search"
# Processing "18aaf072-cfc1-41f9-9d81-d6ba3ab99a17" -> ""
# Processing "6729acba-78c5-40e9-9dbe-570bbfb531ec" -> "/products/PRODUCT/attributes/attribute/Liner"
# Processing "912bd33d-4e49-4a07-a88d-a8f77b89baf3" -> "/products/PRODUCT/attributes/attribute/Width Group"
# Processing "49a1841d-bd9b-4fb6-a31f-97e5aa9b04ef" -> "/products/PRODUCT/sizes/size/sequence"
# Processing "e8a0ad3b-97fb-40bf-a0f8-fc75e6a985c3" -> "/products/PRODUCT/attributes/attribute/Technologies - Footwear"
# Processing "7cecbaaa-030b-40ce-a805-4d2721a846a8" -> "/products/PRODUCT/sizes/size/packagelength"
# Processing "59895173-970b-47bc-bc72-ff8e4360b503" -> "/products/PRODUCT/attributes/attribute/Now Viewing - EU"
# Processing "9e025aac-9d29-49ec-834f-98696c3f18c0" -> "/products/PRODUCT/attributes/attribute/Fit Code"
# Processing "33e12916-9cf6-4f34-9de4-e07d0a2e5701" -> "/products/PRODUCT/productdetails/content/colordescription"
# Processing "71c506c4-af0a-4e4d-bb56-9f74ce072bb1" -> "/products/PRODUCT/attributes/attribute/Never Expire"
# Processing "90934109-8485-4724-a0f0-352fadd22903" -> "/products/PRODUCT/attributes/attribute/ECS Excluded Countries"
# Processing "6f8a3ff3-431b-4c48-8f7c-f6ff6ca8ba66" -> "/products/PRODUCT/attributes/attribute/Shoes"
# Processing "ea3f4974-1254-4033-8061-560885e8afe2" -> "/products/PRODUCT/pdpurl"
# Processing "974d0df0-2312-461b-ba5b-aed123c141b6" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Looking For"
# Processing "bd8639cb-8b61-4a50-a9e4-371adee969cd" -> "/products/PRODUCT/attributes/attribute/Notes"
# Processing "afbb1682-34d8-4748-923f-f000871d0d14" -> "/products/PRODUCT/attributes/attribute/Shirts"
# Processing "5b2de0b7-75aa-4ea9-9968-c18bf85f0424" -> "/products/PRODUCT/attributes/attribute/Product Heat Level - Actual"
# Processing "4ced1549-ad46-4fb7-9896-a4fc1bf8a7fa" -> "/products/PRODUCT/attributes/attribute/Best For - Mens Training Shoes"
# Processing "17f2768b-09a7-4641-ba0d-8986e06ce621" -> "/products/PRODUCT/attributes/attribute/Length"
# Processing "21075d63-145c-4132-87ea-bf0a9103ff43" -> "/products/PRODUCT/attributes/attribute/Pack Size"
# Processing "870917ec-877b-4e28-8fec-3ec1635f1e64" -> "/products/PRODUCT/attributes/attribute/Nike Unlaced"
# Processing "73cd884d-c952-4d0a-ba47-4f8478c66a11" -> "/products/PRODUCT/prices/price"
# Processing "9280a404-4601-46da-9b01-39c78bfe2ae5" -> "/products/PRODUCT/attributes/attribute/Best For - Womens Training Shoes"
# Processing "e6316aa8-dcdc-4e3f-a345-dd6a7ea32276" -> "/products/PRODUCT/attributes/attribute/Jackets and Vests"
# Processing "a58f8575-cbf4-405b-9c22-db9e4dabb46e" -> "/products/PRODUCT/attributes/attribute/PCAT Size Convertors"
# Processing "2a4da3b7-71dc-4b19-aef6-e26ffe77dd61" -> "/products/PRODUCT/attributes/attribute/Shipping Delay"
# Processing "11eb4151-6433-47e2-9114-ad8c49f574b8" -> "/products/PRODUCT/productdetails/content/productnameline1"
# Processing "bb40f9cf-b334-407b-9469-e86629f9a5ab" -> "/products/PRODUCT/sizes"
# Processing "19462a97-b4e0-475a-8936-7e4929f86395" -> "/products/PRODUCT/attributes/attribute/JerseyiDPath"
# Processing "130e6f52-9e84-4dfd-a196-2faf677db0f8" -> "/products/PRODUCT/attributes/attribute/Best For - Running Shoes"
# Processing "9e04de0e-6cce-4d52-88d5-4b2ce4a2938a" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Category-Goal"
# Processing "7b31ac03-e149-4e5e-9d9c-352f2602f927" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Conditions"
# Processing "dedd80a4-f72f-4cf7-b539-dc299ec13bd5" -> "/products/PRODUCT/attributes/attribute/Hide From CSR"
# Processing "c172e17d-9c26-4d25-b81a-099bbe1c2dc3" -> "/products/PRODUCT/productdetails/content/swatchcolor"
# Processing "48d0ce8a-17be-485c-9544-697af386f55d" -> "/products/PRODUCT/images"
# Processing "19914ebe-4cd5-4332-a28f-7ff25f135429" -> "/products/PRODUCT/attributes/attribute/Seasonal Global NV Collections"
# Processing "420e7b28-95b8-4061-8d79-962ed40b0ca4" -> "/products/PRODUCT/attributes/attribute/Hoodies and Sweatshirts"
# Processing "b115fb74-03e7-4693-84da-d68bc2a4b49e" -> "/products/PRODUCT/attributes/attribute/Product Publish Type"
# Processing "55438f53-8c6b-40a2-ae64-a003b372cdbb" -> "/products/PRODUCT/attributes/attribute/Best For - Tennis Shoes"
# Processing "37dd6bc5-82d2-43c5-b824-012988f129a8" -> "/products/PRODUCT/attributes/attribute/Materials"
# Processing "33f3550e-3f4d-4ad2-8676-b93a4244c325" -> "/products/PRODUCT/partnumber"
# Processing "dccbec1e-8b9a-49dd-9514-a8d7dc93cfed" -> "/products/PRODUCT/attributes/attribute/Secondary Simple Colour Description"
# Processing "f1afb7e2-cac2-4aa4-92ab-04e3cebc89ed" -> "/products/PRODUCT/images/image"
# Processing "60d21c19-2fca-4964-84e4-d090c229ba16" -> "/products/PRODUCT/attributes/attribute/Team Global Football Club"
# Processing "2c443112-7cd8-4b6f-826d-a63b620d70fe" -> "/products/PRODUCT/attributes/attribute/Product Type"
# Processing "16491372-d33d-44aa-862c-29045d023766" -> "/products/PRODUCT/attributes/attribute/ProductDisplayOrder"
# Processing "3457a035-fa79-499e-8a83-a8d64238f398" -> "/products/PRODUCT/attributes/attribute/Sock Height"
# Processing "ce8e7975-c9af-42a9-a00f-b6bbbfae529e" -> "/products/PRODUCT"
# Processing "fba0d80a-cbde-43bd-8e10-d67ec88b615a" -> "/products/PRODUCT/attributes/attribute/Coming Soon Countdown Clock"
# Processing "ddf30fff-4cbf-4c84-92de-0d6937ad7135" -> "/products/PRODUCT/attributes/attribute/Technologies - Apparel and EQ"
# Processing "56564432-2a3f-4b32-8bcc-ed3c7bf23114" -> "/products/PRODUCT/attributes/attribute/Keywords"
# Processing "e66c9d9e-7691-4ba5-8d5b-0fd392ff361c" -> "/products/PRODUCT/attributes/attribute/In Wall Content - Preview"
# Processing "a5a9ddc7-fef1-4993-94b4-475c49d72216" -> "/products/PRODUCT/attributes/attribute/Outdoor Conditions"
# Processing "a0e9225c-34ab-4a89-a12d-2b7826b0c9eb" -> "/products/PRODUCT/attributes/attribute/Shop By Price"
# Processing "dfdc9f6f-e91f-4f49-959c-22f09875d058" -> "/products/PRODUCT/attributes/attribute/Digital Season"
# Processing "b3bf5f9e-1581-437b-a7aa-804bcefeb421" -> "/products/PRODUCT/attributes/attribute/Endeca Primary Simple Colour"
# Processing "258ebe5c-89a5-432e-98b0-8c5a2bac5aa2" -> "/products/PRODUCT/attributes/attribute/Global Football Surfaces"
# Processing "44f4dd88-c0ca-4e9e-973a-3888667da3f0" -> "/products/PRODUCT/attributes/attribute/Hem Shape"
# Processing "b021917c-33bc-4670-8020-d9e05320d55b" -> "/products/PRODUCT/sizes/size/id (a)"
# Processing "c1b58815-0c76-4a0b-8927-d79d62c99f8d" -> "/products/PRODUCT/attributes/attribute/Sport - Primary"
# Processing "c6a0f980-78ff-4751-8210-b7ce426d9802" -> "/products/PRODUCT/attributes/attribute/Gender"
# Processing "c11d6095-536a-4d17-8d96-4e58642b5214" -> "/products/PRODUCT/attributes/attribute/Sock Type"
# Processing "1645d338-708f-4109-ad67-aa0a3dd24d97" -> "/products/PRODUCT/sizes/size/grosspackageweight"
# Processing "56286015-c6e1-46a2-95c8-da8ae98d5ae6" -> "/products/PRODUCT/attributes/attribute/Running Shoe Benefit"
# Processing "f5c8503c-8ce0-4f3b-9001-f38e1f3b582f" -> "/products/PRODUCT/attributes/attribute/Accessories and Equipment"
# Processing "12087fca-f81a-4fc2-b66f-5c820e063408" -> "/products/PRODUCT/attributes/attribute/NIKEiD Match Style"
# Processing "842b61c9-ead3-4720-bca9-9f0b42a91155" -> "/products/PRODUCT/attributes/attribute/Sets"
# Processing "cb71d16e-b524-4ab3-8fc6-b36d38164e0f" -> "/products/PRODUCT/attributes/attribute/Category"
# Processing "db284728-9990-433f-8f82-b1bc1f33deb0" -> "/products/PRODUCT/attributes/attribute/Swatch Color Description"
# Processing "c8b1de40-e3ff-4904-a5fc-ce27b93e6309" -> "/products/PRODUCT/attributes/attribute/Jersey Type"
# Processing "b1ad0482-7d8f-49ad-9365-b48701a22d09" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Fit"
# Processing "37a2ef1d-2116-41d6-bec8-b84fef4ef70a" -> "/products/PRODUCT/enddate"
# Processing "6b8f62e4-958a-4450-b539-c2201b23dd5a" -> "/products/PRODUCT/productdetails/content/productnameline2"
# Processing "c63f302d-7e4a-4809-a403-846d97b95822" -> "/products/PRODUCT/attributes/attribute/Prints"
# Processing "5d290395-c00e-4827-b0aa-2db46977d30a" -> "/products/PRODUCT/attributes/attribute"
# Processing "21d4a860-f20b-4e4e-adfb-1f026cb10c13" -> "/products/PRODUCT/attributes/attribute/Shoe Type"
# Processing "216f9b31-f199-40ac-8476-e9ec8c396bee" -> "/products/PRODUCT/attributes/attribute/Class Id"
# Processing "261e81ee-3c26-4881-adc9-83f1cbdc8112" -> "/products/PRODUCT/attributes/attribute/Promotion Inclusion"
# Processing "46b8fba1-957a-4dbd-a002-f1b45da993db" -> "/products/PRODUCT/attributes/attribute/Socks"
# Processing "95d6e5d8-4bd4-4679-bfca-9f7d6a09951a" -> "/products/PRODUCT/attributes/attribute/SizeChart"
# Processing "0ffaf386-fa01-4145-ab3d-696e7b901a36" -> "/products/PRODUCT/attributes/attribute/NBA Athlete"
# Processing "f5a629b2-311e-483e-be66-eff50844e131" -> "/products/PRODUCT/attributes/attribute/Sustainability"
# Processing "b7fd4a49-7968-4a2c-b4c2-eceb94f80623" -> "/products/PRODUCT/productdetails/content/productslug"
# Processing "15fa3beb-ef8f-4000-b724-48fe25977a9f" -> "/products/PRODUCT/attributes/attribute/Kids Age"
# Processing "1630ee14-8398-4ab4-aa3b-44608aa77ed0" -> "/products/PRODUCT/producttype"
# Processing "4160e1d1-9679-476d-aacc-9a04e9fd6c1e" -> "/products/PRODUCT/productdetails/content"
# Processing "1ad248a2-f47e-4874-aa76-60f76f461b40" -> "/products/PRODUCT/productdetails/content/longdescription"
# Processing "7a9fcd9e-5b4c-4ccf-a98a-559c17ca91a1" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Bra Type"
# Processing "1d8c0c3f-42bd-43b7-b930-e07e0e6f9fda" -> "/products/PRODUCT/attributes/attribute/z_DNU_Socks"
# Processing "de628997-ee28-408d-97bb-1db1b27761bb" -> "/products/PRODUCT/attributes/attribute/Model - Air Max"
# Processing "65aadf96-4b75-465a-aafc-9675d32b9e45" -> "/products/PRODUCT/attributes/attribute/Global Evergreen NV Collections"
# Processing "ca7dab1f-35be-4ba3-862f-930de40f3ffd" -> "/products/PRODUCT/attributes/attribute/Width"
# Processing "8dc932ac-cd45-4d26-b143-1d6d81af9de8" -> "/products/PRODUCT/attributes/attribute/Underwear"
# Processing "2f52c71b-e91c-4415-99f9-8f19872810e9" -> "/products/PRODUCT/attributes/attribute/Bodysuits"
# Processing "6a095d39-8e7b-48d8-8b8b-bcad09057f0d" -> "/products/PRODUCT/sizes/size/gtin"
# Processing "fdb69fdf-666f-46b8-b38e-6555c3e249bc" -> "/products/PRODUCT/sizes/size/size"
# Processing "9416c63c-49cd-4a3b-85cf-220ff5310a24" -> "/products/PRODUCT/attributes/attribute/giftmessage"
# Processing "d52b3d95-8a0a-4bd3-997b-f52d58b1478b" -> "/products/PRODUCT/attributes/attribute/Surfaces"
# Processing "947689aa-09d2-4403-ae36-a8c638bfdd27" -> "/products/PRODUCT/attributes/attribute/Rise"
# Processing "8d64fca4-9ed6-4e69-a206-c50de19bbab5" -> "/products/PRODUCT/images/image/imageDisplayOrder"
# Processing "f2d651e7-298c-43d6-afce-ea45543c93ed" -> "/products/PRODUCT/attributes/attribute/Inseam Length"
# Processing "f2d7107e-01d8-4280-8987-e93231f27c1e" -> "/products/PRODUCT/attributes/attribute/Team NBA"
# Processing "e7cba352-dc6f-4896-b0d2-b652038197fa" -> "/products/PRODUCT/attributes/attribute/Sales Channel"
# Processing "9c9197a4-3d5a-4699-8b42-074974eb454c" -> "/products/PRODUCT/attributes/attribute/KMS Copy"
# Processing "7fd24fe6-8010-44a8-8052-3d225afecdc2" -> "/products/PRODUCT/attributes/attribute/Path Name"
# Processing "fd9f70e1-0a22-4ce1-91bd-94de090869fc" -> "/products/PRODUCT/sizes/size"
# Processing "121da159-8e11-45e5-9815-ddcbb13bc50b" -> "/products/PRODUCT/attributes/attribute/Hats and Headwear"
# Processing "5719757c-056b-448a-aecf-6ebd76b5a04b" -> "/products/PRODUCT/attributes/attribute/ETL-Derived-ModelTypeName"
# Processing "306b3824-e9e1-42a7-b9ec-eff13936c803" -> "/products/PRODUCT/attributes/attribute/Hidden Collections - EU"
# Processing "9d583f5a-3897-4b60-8ddd-1f44e4763b0b" -> "/products/PRODUCT/attributes/attribute/Recurring Seasonal NV Collection"
# Processing "7b0c8134-8339-4d5a-8adc-94638b4041df" -> "/products/PRODUCT/attributes/attribute/Tops and T-Shirts"
# Processing "76756c55-29f8-41de-9f1a-3e4acc2fb9c4" -> "/products/PRODUCT/attributes/attribute/Brand"
# Processing "b3aa70cf-ef35-4614-96b8-0124f90e993c" -> "/products/PRODUCT/attributes/attribute/Logo Color"
# Processing "aa5288c9-3435-44d4-9fd9-ed49d6cf5afd" -> "/products/PRODUCT/attributes/attribute/Team NFL"
# Processing "936842e1-b16d-4c59-84f1-96a6c4d0e53b" -> "/products/PRODUCT/attributes/attribute/Sports"
# Processing "36876a7f-95be-4227-8384-ac0bd2b6de75" -> "/products/PRODUCT/productgroupid"
# Processing "1ecbb0a6-9a9e-4e40-9cf1-4990b5c2d640" -> "/products/PRODUCT/attributes/attribute/Legacy PID Cleanup"
# Processing "e63714d0-a0e7-464e-99bd-1c271cdb815b" -> "/products/PRODUCT/attributes/attribute/NikeConnect Technology"
# Processing "c0f7a76e-5b51-424c-8c14-821eaadf3990" -> "/products/PRODUCT/attributes/attribute/Channel Collection"
# Processing "af65a054-3044-4a84-9c90-984704e621fa" -> "/products/PRODUCT/attributes/attribute/Primary Color"
# Processing "cebef38f-d480-48e1-bf0e-6a0a054b96fb" -> "/products/PRODUCT/attributes/attribute/Marketplace Initiative"
# Processing "10c564db-bdde-436f-8dd0-b90f00193936" -> "/products/PRODUCT/attributes/attribute/Model"
# Processing "f1cf56c7-565e-4c2f-a10e-9752cb3f0349" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Athlete"
# Processing "04b052b2-f841-416e-854e-c4b51164bb7d" -> "/products/PRODUCT/attributes/attribute/Sports Bras"
# Processing "34299a02-2530-4ef5-b36f-83df00f8db2b" -> "/products/PRODUCT/attributes/attribute/Inventory Share Off"
# Processing "be84f267-82ff-4a0e-b6bf-7b3309cf2fbb" -> "/products/PRODUCT/attributes/attribute/Additional Sizing"
# Processing "c4f63175-825b-41ab-8c86-3fd113ef42da" -> "/products/PRODUCT/productdetails/content/productname"
# Processing "fd3332fa-d263-4e27-9a32-f29d91f8d4db" -> "/products/PRODUCT/prices/price/priceclass"
# Processing "0890673a-0df3-47f1-b9ac-a5c002c5ea99" -> "/products/PRODUCT/attributes/attribute/Product Heat Level"
# Processing "50ca6d80-4584-4925-91a5-9ba632e9b456" -> "/products/PRODUCT/attributes/attribute/National Teams"
# Processing "ddf8ca60-1a9a-467d-a066-e7c6b7aafa14" -> "/products/PRODUCT/sizes/size/packagewidth"
# Processing "b84f65c2-e6d1-4697-b2e5-9ff081de7f23" -> "/products/PRODUCT/attributes/attribute/Kids Clothing Size"
# Processing "389b9294-2b00-48ea-b719-48e99493461d" -> "/products/PRODUCT/attributes/attribute/Running Shoe Style"
# Processing "f19355ae-08cc-48b6-a4bd-507229df7d6d" -> "/products/PRODUCT/attributes/attribute/Fan Gear Gender"
# Processing "3b5350c3-9c48-49dd-89d0-43d378a2ce7c" -> "/products/PRODUCT/attributes/attribute/OneNike Size & Fit"
# Processing "53affee0-b068-4192-8602-a8851518c982" -> "/products/PRODUCT/attributes/attribute/Kids Shoe Size"
# Processing "1e7b3b03-5cc1-4ac8-9f80-e4a6ad8d1003" -> "/products/PRODUCT/attributes/attribute/Nike Unlaced Collections"
# Processing "1c6a9858-c927-4878-86fa-ba27f23eff2a" -> "/products/PRODUCT/prices/price/currency (a)"
# Processing "489f3faa-2176-4c1c-a467-0941b98e4f10" -> "/products/PRODUCT/attributes/attribute/Builder Version"
# Processing "ab13746d-4f84-4dab-aa64-ea89d8ed48b8" -> "/products/PRODUCT/attributes/attribute/Icon"
# Processing "988b4cfe-73f8-4bf4-ab2b-974a1927e58d" -> "/products/PRODUCT/attributes/attribute/Sports Bras Style"
# Processing "07f8c7a8-b652-43c4-a9b4-fc19a10c1aeb" -> "/products/PRODUCT/attributes"
# Processing "7a469cd2-4f5d-42dc-b696-18afb181c6aa" -> "/products/PRODUCT/attributes/attribute/JerseyiDSKU"
# Processing "18c4c04f-e74c-4269-a71a-8c44313a369e" -> "/products/PRODUCT/attributes/attribute/NIKEiD Match"
# Processing "a4b4e08f-03ba-4d84-9ba3-1a13880eeedb" -> "/products/PRODUCT/colornumber"
# Processing "e27c0232-fdb5-4257-96b8-694638d1155e" -> "/products/PRODUCT/sizes/size/netweight"
# Processing "c2621d28-635e-4dbb-91b0-7da6e10f88b3" -> "/products/PRODUCT/attributes/attribute/Tertiary Color"
# Processing "9cb92d69-9a98-4f73-9fa2-a79caf2da68f" -> "/products/PRODUCT/prices/price/currentretailprice"
# Processing "1320659c-8621-457d-8d0d-0c1ea237945b" -> "/products/PRODUCT/attributes/attribute/Closure Type"
# Processing "3795a820-e7dc-4b1a-b8da-997b624f518c" -> "/products/PRODUCT/attributes/attribute/Nike Pro Collections"
# Processing "87b1835d-c991-4719-be24-de9843149b2e" -> "/products/PRODUCT/attributes/attribute/Promotion Exclusion"
# Processing "d9daa742-6600-4f23-abc5-542343d2427e" -> "/products/PRODUCT/attributes/attribute/Basketball Surfaces"
# Processing "493c56a3-2fdd-469e-b7d3-bb7af69bf210" -> "/products/PRODUCT/attributes/attribute/AB Test"
# Processing "d8329034-0f8e-4d8f-9c27-108a4e7410dc" -> "/products/PRODUCT/attributes/attribute/Shoe Finder"
# Processing "3297d1e2-84aa-40d9-a9be-42f16c8fb98b" -> "/products"
# Processing "ca037ee1-f9dc-431d-ab9f-064f41e0a16a" -> "/products/PRODUCT/attributes/attribute/Excluded Countries"
# Processing "ead56d62-759d-49ac-8b27-b7bd29717397" -> "/products/PRODUCT/productdetails"
# Processing "816d6a5e-7d48-4aaf-be60-b3ddc3f5471a" -> "/products/PRODUCT/attributes/attribute/New Release"
# Processing "19514e0f-12d5-486d-bb53-2c3891f621a6" -> "/products/PRODUCT/attributes/attribute/Quantity Limit"
# Processing "aec0a1e7-1589-42b6-baf3-46a6001ad120" -> "/products/PRODUCT/attributes/attribute/Jumpsuits and Rompers"
# Processing "7a350cd6-6f3e-498b-991c-df27decd25e1" -> "/products/PRODUCT/attributes/attribute/League"
# Processing "66ea7fa1-6333-4de3-b2a9-935eb245f784" -> "/products/PRODUCT/attributes/attribute/Sleeve Length"
# Processing "0dfbe6d9-633d-4eca-81e9-8de7ff94f45b" -> "/products/PRODUCT/attributes/attribute/Shoe Height"
# Processing "dcc47ec0-5ddb-4664-b2a8-4eac97b78488" -> "/products/PRODUCT/attributes/attribute/Fits"
# Processing "d6d674c6-d57a-4590-b3f9-21f7efe45261" -> "/products/PRODUCT/attributes/attribute/Tracksuits"
# Processing "08ac597f-77cf-4b94-9e98-8598dc2cdf3e" -> "/products/PRODUCT/stylenumber"
# Processing "cd888fd7-7f0d-4b1f-a1e9-3dd782a36467" -> "/products/PRODUCT/attributes/attribute/Running Surfaces"
# Processing "9a419d9f-6cb9-41e9-8ebf-9a5c70fc0ec6" -> "/products/PRODUCT/attributes/attribute/NFL Athlete"
# Processing "fb1320e5-32ea-4e26-96df-22d83d4c6da5" -> "/products/PRODUCT/attributes/attribute/Hard Launch Indicator"
# Processing "20c41af9-83d1-4111-96e4-f3c983d5c23a" -> "/products/PRODUCT/niketype"
# Processing "68346310-4f6a-4902-8565-30687a14b650" -> "/products/PRODUCT/attributes/attribute/Inventory Override Indicator"
# Processing "9e9c0d13-13b9-4786-bd2c-09e2a1135dad" -> "/products/PRODUCT/attributes/attribute/Nike Free Shoe Type"
# Processing "50f16b18-db6b-4add-b649-f24d91f6de6d" -> "/products/PRODUCT/prices/price/originalretailprice"
# Processing "8e4f558a-dbbc-4312-ada1-f5ddb5660265" -> "/products/PRODUCT/attributes/attribute/Shorts"
# Processing "e93f3dbe-8eab-4353-8e45-53696737a2a9" -> "/products/PRODUCT/images/image/imageUrl"
# Processing "122cb700-4596-49c1-8b05-a7c5d9c67425" -> "/products/PRODUCT/attributes/attribute/GEAR UP - Cup Size"
# Processing "437c14dd-94dc-4a33-9b66-977971ba444f" -> "/products/PRODUCT/attributes/attribute/Neck Type"
# Processing "d7ab1b6a-0fa2-4ac8-b855-c530b2f425d8" -> "/products/PRODUCT/attributes/attribute/Partner Programs"
# Processing "6b747897-e54c-4e39-931f-5a35e4d7718a" -> "/products/PRODUCT/prices"
# Processing "439dee0f-5794-4545-82ef-3afb95749ae8" -> "/products/PRODUCT/attributes/attribute/giftwrap"
# Processing "85460bd9-5fdc-406c-987c-0a627526c60d" -> "/products/PRODUCT/status"
# Processing "9717fb3e-27f7-4395-94a6-3423a3af1410" -> "/products/PRODUCT/productid (a)"
# Processing "4290cbde-b020-446b-9491-7a67ce6a196c" -> "/products/PRODUCT/maincolorway"
# Processing "7142742b-f1a2-4a89-bd4b-cd9fce566dee" -> "/products/PRODUCT/attributes/attribute/Surf and Swimwear"
# Processing "d30927eb-7af8-4949-8be0-7cb930d9df51" -> "/products/PRODUCT/attributes/attribute/Best For - Cross Category"
# Processing "a40ca1e9-91a1-4599-a804-55e54d6f6d17" -> "/products/PRODUCT/sizes/size/vatcode"
# Processing "dd3cfde0-aa81-4ef6-9642-e959f58a3a50" -> "/products/PRODUCT/attributes/attribute/Division Code"
# Processing "2f2e89eb-0f7c-498e-bc01-fe6a7ee60560" -> "/products/PRODUCT/attributes/attribute/Global Launch NV Collection"
# Processing "923087f4-b0fc-4786-99b7-3d1f437c9ba4" -> "/products/PRODUCT/attributes/attribute/Jersey Classification"
# Processing "f3b901c0-13ef-476d-a5c7-557d127d41fe" -> "/products/PRODUCT/attributes/attribute/Skirts and Dresses"
# Processing "4f5313ae-d831-4ce6-874f-f167230a0475" -> "/products/PRODUCT/attributes/attribute/Collar Type"
# Processing "83114f78-2f85-4b78-8185-6c8a9706f87b" -> "/products/PRODUCT/attributes/attribute/Base Layers"
# Processing "d375fbb1-e235-4d57-8555-07afa3995986" -> "/products/PRODUCT/attributes/attribute/Jordan Editions"
# Processing "cd1161c2-ae73-451b-bca8-743eabdfc944" -> "/products/PRODUCT/attributes/attribute/Kits"
# Processing "f22c3e7a-f53c-4f54-884d-1281a4212afe" -> "/products/PRODUCT/startdate"
# Processing "027380c7-cbbe-423d-9d5c-084a3dbc1536" -> "/products/PRODUCT/attributes/attribute/Notify Me Indicator"
# Processing "5d5610ec-47d4-4bb7-871d-2a76f80d25b8" -> "/products/PRODUCT/attributes/attribute/Event"
# Processing "87472895-8d2e-497e-876f-05a98152fdff" -> "/products/PRODUCT/attributes/attribute/Pants and Tights"
# IGNORED:  ['ab13746d-4f84-4dab-aa64-ea89d8ed48b8.distinct', '6729acba-78c5-40e9-9dbe-570bbfb531ec.distinct', 'f22c3e7a-f53c-4f54-884d-1281a4212afe.distinct', '3457a035-fa79-499e-8a83-a8d64238f398.distinct', '08ac597f-77cf-4b94-9e98-8598dc2cdf3e.distinct', '936842e1-b16d-4c59-84f1-96a6c4d0e53b.distinct', '8cf69d48-61c6-4f24-b167-0c625d89c457.distinct', 'b115fb74-03e7-4693-84da-d68bc2a4b49e.distinct', '50ca6d80-4584-4925-91a5-9ba632e9b456.distinct', 'de628997-ee28-408d-97bb-1db1b27761bb.distinct', 'be84f267-82ff-4a0e-b6bf-7b3309cf2fbb.distinct', 'b5cf9315-b6c2-42ed-b037-d647e5c96bbc.distinct', '66ea7fa1-6333-4de3-b2a9-935eb245f784.distinct', '49a1841d-bd9b-4fb6-a31f-97e5aa9b04ef.distinct', '7b0c8134-8339-4d5a-8adc-94638b4041df.distinct', '0890673a-0df3-47f1-b9ac-a5c002c5ea99.distinct', '9c9197a4-3d5a-4699-8b42-074974eb454c.distinct', '48d0ce8a-17be-485c-9544-697af386f55d.distinct', '6d5eb2ea-e3d6-4d6a-9d05-6598a9dbaad7.distinct', 'b021917c-33bc-4670-8020-d9e05320d55b.distinct', 'b3bf5f9e-1581-437b-a7aa-804bcefeb421.distinct', '71c506c4-af0a-4e4d-bb56-9f74ce072bb1.distinct', 'afbb1682-34d8-4748-923f-f000871d0d14.distinct', '8d64fca4-9ed6-4e69-a206-c50de19bbab5.distinct', '5d290395-c00e-4827-b0aa-2db46977d30a.distinct', '37a2ef1d-2116-41d6-bec8-b84fef4ef70a.distinct', 'b84f65c2-e6d1-4697-b2e5-9ff081de7f23.distinct', '8dc932ac-cd45-4d26-b143-1d6d81af9de8.distinct', '121da159-8e11-45e5-9815-ddcbb13bc50b.distinct', '2f2e89eb-0f7c-498e-bc01-fe6a7ee60560.distinct', '258ebe5c-89a5-432e-98b0-8c5a2bac5aa2.distinct', '20c41af9-83d1-4111-96e4-f3c983d5c23a.distinct', '19462a97-b4e0-475a-8936-7e4929f86395.distinct', '8baa74b4-3180-414e-ac9a-05dcfddf1dd4.distinct', '870917ec-877b-4e28-8fec-3ec1635f1e64.distinct', 'b7fd4a49-7968-4a2c-b4c2-eceb94f80623.distinct', '87b1835d-c991-4719-be24-de9843149b2e.distinct', 'd52b3d95-8a0a-4bd3-997b-f52d58b1478b.distinct', '19914ebe-4cd5-4332-a28f-7ff25f135429.distinct', '5d5610ec-47d4-4bb7-871d-2a76f80d25b8.distinct', '65aadf96-4b75-465a-aafc-9675d32b9e45.distinct', 'b3aa70cf-ef35-4614-96b8-0124f90e993c.distinct', '7a1e72e0-1116-449e-bcc2-46df87f574d5.distinct', '9647cbf9-ab8c-4cf4-a612-037fc22b5f63.distinct', 'c1b58815-0c76-4a0b-8927-d79d62c99f8d.distinct', '332e87ca-0fc3-4972-9da5-b200ea36cdad.distinct', '44dc383c-7386-4fa0-aea8-6217b855b57e.distinct', '130e6f52-9e84-4dfd-a196-2faf677db0f8.distinct', 'e27c0232-fdb5-4257-96b8-694638d1155e.distinct', 'dfdc9f6f-e91f-4f49-959c-22f09875d058.distinct', '9cb92d69-9a98-4f73-9fa2-a79caf2da68f.distinct', '85460bd9-5fdc-406c-987c-0a627526c60d.distinct', '16491372-d33d-44aa-862c-29045d023766.distinct', 'cb71d16e-b524-4ab3-8fc6-b36d38164e0f.distinct', '842b61c9-ead3-4720-bca9-9f0b42a91155.distinct', '66b7477b-5de8-43fd-a898-ba8385e12346.distinct', '9280a404-4601-46da-9b01-39c78bfe2ae5.distinct', 'c0f7a76e-5b51-424c-8c14-821eaadf3990.distinct', 'fb1320e5-32ea-4e26-96df-22d83d4c6da5.distinct', 'd9daa742-6600-4f23-abc5-542343d2427e.distinct', 'a40ca1e9-91a1-4599-a804-55e54d6f6d17.distinct', '55438f53-8c6b-40a2-ae64-a003b372cdbb.distinct', 'ce8e7975-c9af-42a9-a00f-b6bbbfae529e.distinct', '12087fca-f81a-4fc2-b66f-5c820e063408.distinct', 'e511878a-fb0a-4d07-8e26-f6f0e99b9307.distinct', '1ecbb0a6-9a9e-4e40-9cf1-4990b5c2d640.distinct', 'af65a054-3044-4a84-9c90-984704e621fa.distinct', '36876a7f-95be-4227-8384-ac0bd2b6de75.distinct', 'a58f8575-cbf4-405b-9c22-db9e4dabb46e.distinct', '1645d338-708f-4109-ad67-aa0a3dd24d97.distinct', '44f4dd88-c0ca-4e9e-973a-3888667da3f0.distinct', 'd30927eb-7af8-4949-8be0-7cb930d9df51.distinct', '9e025aac-9d29-49ec-834f-98696c3f18c0.distinct', '7142742b-f1a2-4a89-bd4b-cd9fce566dee.distinct', 'f5a629b2-311e-483e-be66-eff50844e131.distinct', '11eb4151-6433-47e2-9114-ad8c49f574b8.distinct', 'dcc47ec0-5ddb-4664-b2a8-4eac97b78488.distinct', '3795a820-e7dc-4b1a-b8da-997b624f518c.distinct', '53affee0-b068-4192-8602-a8851518c982.distinct', 'c172e17d-9c26-4d25-b81a-099bbe1c2dc3.distinct', '90934109-8485-4724-a0f0-352fadd22903.distinct', '4160e1d1-9679-476d- ...
# Saving to parquet
# Write process took 0:01:05.883698 seconds.

# %%
import pandas as pd

print('Creating dataframe task (myfile_samples): ', datetime.now())

myfile_labels = pd.read_parquet('myfile_labels.parquet')
myfile_samples = pd.read_parquet('myfile_values.parquet')

#print('Starting task (myfile_samples): ', datetime.now())

# this operation is now handled by convert_string_lists_to_lists in a later step
#myfile_samples = myfile_samples['values'].apply(literal_eval)

#print('Finished task (myfile_samples): ', datetime.now())
# Out:
# Creating dataframe task (myfile_samples):  2021-02-09 17:51:49.858011

# %%
myfile_labels.head(50)
# Out:
#                                                  type
# 1   /products/PRODUCT/attributes/attribute/Access ...
# 2          /products/PRODUCT/sizes/size/packageheight
# 3   /products/PRODUCT/attributes/attribute/Simple ...
# 4          /products/PRODUCT/prices/price/country (a)
# 5     /products/PRODUCT/attributes/attribute/Hat Type
# 6     /products/PRODUCT/attributes/attribute/Bag Type
# 7   /products/PRODUCT/attributes/attribute/Gift Co...
# 8   /products/PRODUCT/attributes/attribute/Store -...
# 9   /products/PRODUCT/attributes/attribute/Global ...
# 10  /products/PRODUCT/attributes/attribute/CMS Enh...
# 11  /products/PRODUCT/attributes/attribute/Jersey ...
# 12                     /products/PRODUCT/widthgroupid
# 13  /products/PRODUCT/attributes/attribute/Best Fo...
# 14  /products/PRODUCT/attributes/attribute/GEAR UP...
# 15  /products/PRODUCT/attributes/attribute/Best Fo...
# 16       /products/PRODUCT/attributes/attribute/Gifts
# 17  /products/PRODUCT/attributes/attribute/Seconda...
# 18     /products/PRODUCT/attributes/attribute/Athlete
# 19     /products/PRODUCT/attributes/attribute/Details
# 20  /products/PRODUCT/attributes/attribute/Endeca ...
# 21  /products/PRODUCT/attributes/attribute/Hide Fr...
# 22
# 23       /products/PRODUCT/attributes/attribute/Liner
# 24  /products/PRODUCT/attributes/attribute/Width G...
# 25              /products/PRODUCT/sizes/size/sequence
# 26  /products/PRODUCT/attributes/attribute/Technol...
# 27         /products/PRODUCT/sizes/size/packagelength
# 28  /products/PRODUCT/attributes/attribute/Now Vie...
# 29    /products/PRODUCT/attributes/attribute/Fit Code
# 30  /products/PRODUCT/productdetails/content/color...
# 31  /products/PRODUCT/attributes/attribute/Never E...
# 32  /products/PRODUCT/attributes/attribute/ECS Exc...
# 33       /products/PRODUCT/attributes/attribute/Shoes
# 34                           /products/PRODUCT/pdpurl
# 35  /products/PRODUCT/attributes/attribute/GEAR UP...
# 36       /products/PRODUCT/attributes/attribute/Notes
# 37      /products/PRODUCT/attributes/attribute/Shirts
# 38  /products/PRODUCT/attributes/attribute/Product...
# 39  /products/PRODUCT/attributes/attribute/Best Fo...
# 40      /products/PRODUCT/attributes/attribute/Length
# 41   /products/PRODUCT/attributes/attribute/Pack Size
# 42  /products/PRODUCT/attributes/attribute/Nike Un...
# 43                     /products/PRODUCT/prices/price
# 44  /products/PRODUCT/attributes/attribute/Best Fo...
# 45  /products/PRODUCT/attributes/attribute/Jackets...
# 46  /products/PRODUCT/attributes/attribute/PCAT Si...
# 47  /products/PRODUCT/attributes/attribute/Shippin...
# 48  /products/PRODUCT/productdetails/content/produ...
# 49                            /products/PRODUCT/sizes
# 50  /products/PRODUCT/attributes/attribute/Jerseyi...

# %%
myfile_samples.head(20)
# Out:
#                                                values
# 1   ['true', 'true', 'true', 'true', 'true', 'true...
# 2   [7.7978, 7.7978, 7.8, 8.89, 7.8, 8.763, 7.8, 8...
# 3   ['Black', 'Black', 'Black', 'Black', 'Black', ...
# 4   ['AT', 'BE', 'CZ', 'DE', 'DK', 'ES', 'FI', 'FR...
# 5   ['Adjustable', 'Adjustable', 'Adjustable', 'Ad...
# 6   ['Backpack', 'Backpack', 'Backpack', 'Backpack...
# 7   ['Just Dropped', 'Just Dropped', 'Just Dropped...
# 8   ['FCBarcelona', 'FCBarcelona', 'FCBarcelona', ...
# 9   ['Use - Off the pitch', 'Use - Off the pitch',...
# 10  ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Ye...
# 11  ['Game', 'Game', 'Game', 'Game', 'Game', 'Game...
# 12  ['Nike Air Force 1 Kids Rollup', 'Nike Air For...
# 13  ['z_DNU_Strike', 'z_DNU_Strike', 'z_DNU_Strike...
# 14  ['Clothing', 'Clothing', 'Clothing', 'Clothing...
# 15  ['Staying Dry', 'Staying Dry', 'Staying Dry', ...
# 16  ['All', 'All', 'All', 'All', 'All', 'All', 'Al...
# 17  ['Tidal Blue', 'Tidal Blue', 'Tidal Blue', 'Ti...
# 18  ['Cam Newton', 'Cam Newton', 'Cam Newton', 'Ca...
# 19  ['Hooded', 'Hooded', 'Pockets', 'Pockets', 'Po...
# 20  ['Grey', 'Grey', 'Grey', 'Grey', 'Grey', 'Grey...

# %%
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
import tensorflow as tf

from sherlock import helpers
#from sherlock.features.preprocessing import extract_features, convert_string_lists_to_lists, prepare_feature_extraction
from sherlock.functional import extract_features_to_csv
from sherlock.deploy.predict_sherlock import predict_sherlock

# %% [markdown]
# ## Extract features
# It is important that the string-representations of lists are first converted into lists of strings.
# The labels should be a list of semantic types.

# %% [markdown]
# ### Given that feature extraction can take long, we only take the first 100 samples.

# %%
#y_test_subset = y_test[:100]

# %%
# %load_ext line_profiler

# %%
# ensure embedding initialisation is outside of timing for extract_features
from sherlock.features.word_embeddings import initialise_word_embeddings
from sherlock.features.paragraph_vectors import initialise_pretrained_model, initialise_nltk
from sherlock.features.preprocessing import prepare_feature_extraction

prepare_feature_extraction()
initialise_word_embeddings()
initialise_pretrained_model(400)
initialise_nltk()

# %%
start = datetime.now()

print(f'processing {myfile_samples["values"]}')

#%lprun -m sherlock.features.preprocessing extract_features_to_csv('output2.csv', myfile_samples.head(n=100))
extract_features_to_csv('output2.csv', myfile_samples["values"].head(n=100))


#X_test = extract_features('output.csv', test_samples_converted.head(n=100))

end = datetime.now()
x = end - start
print(f'Extract Features process took {x} seconds.')

# %%
# Baseline (before changes)
# Extract Features process took 0:03:11.954844 seconds.

# Tuning iterations
# Extract Features process took 0:00:13.869183 seconds. (cache Word Embeddings)
# Extract Features process took 0:00:06.143361 seconds. (cache Doc2Vec)
# Extract Features process took 0:00:01.308678 seconds. (improved computation for bag of character features)
# Extract Features process took 0:00:01.259591 seconds. (smaller optimisation tweaks - string cat, removal of double compute of some stats)
# Extract Features process took 0:00:00.650005 seconds. (use arrays not pd.Series for stats, series.str.count is also inefficient compared to loops)
# Extract Features process took 0:00:00.320845 seconds. (replace np stats calcs, unique values calc)

# %%
X_test = pd.read_csv('output2.csv', dtype=np.float32)

print(X_test)

# %%
import pandas as pd
import numpy as np

from sherlock.deploy.predict_sherlock import predict_sherlock
from datetime import datetime
from sklearn.metrics import f1_score, classification_report

# %%
predicted_labels = predict_sherlock(X_test, nn_id='retrained_sherlock10')

# %%
print(predicted_labels)

# %%
labels={}

labels['product_brandGender2'] = 'gender'
labels['product_ageGroup1'] = 'gender'
labels['product_sportPurpose3'] = 'description'
labels['product_sportPurpose4'] = 'description'
labels['product_sportPurpose2'] = 'description'
labels['product_brandCategory4_footwear'] = 'description'
labels['article_brandColourName'] = 'colour'
labels['product_brandCategory1'] = 'category'
labels['article_id'] = 'code'
labels['product_brandGender1'] = 'gender'
labels['product_type'] = 'code'
labels['article_brandSize'] = 'code'
labels['product_ageGroup2'] = 'gender'
labels['product_brandSeason'] = 'code'
labels['product_brandSizeGrid'] = 'code'
labels['product_sportPurpose1'] = 'description'
labels['product_primaryCategoryIdCode'] = 'code'
labels['product_id'] = 'code'
labels['product_brandCategory3'] = 'category'
labels['product_brandCategory2'] = 'category'

y_test=list(labels.values())

# %%
f1_score(y_test, predicted_labels, average="weighted")
